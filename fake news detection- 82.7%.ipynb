# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.set_option('Display.max_colwidth', None)
df = pd.read_csv('news.csv')
# Out:
# C:\Users\willi\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\willi\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\willi\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)
# C:\Users\willi\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
len(df)
# Out:
# 6335

# %%
df['label'].hist()
# Out:
# <AxesSubplot:>

# %%
import re
import nltk
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk import RegexpParser
from nltk.corpus import stopwords
nltk.download('wordnet')
nltk.download('Punkt')
import string
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\willi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Error loading Punkt: Package 'Punkt' not found in index

# %%
def lower(text):
    new_text = text.lower()
    return new_text

# %%
def remove_punc(text):
    new_text = re.sub(r'[^\w\s]', '',text)
    return new_text

# %%
def remove_stopwords(text):
    stop = set(stopwords.words('english'))
    new_text = ' '.join(word for word in text.split() if word not in stop)
    return new_text

# %%
def bigrams(tokens, sep=' ', n=2):
    return [sep.join(bigram) for bigram in zip(*[tokens[i:] for i in range(n)])]

# %%
df['new_title'] = df['title'].apply(lambda x: x.lower())

# %%
df['new_title'] = df['new_title'].apply(remove_punc)

# %%
df['new_title'] = df['new_title'].apply(remove_stopwords)

# %%
df['new_text'] = df['text'].apply(lambda x: x.lower())

# %%
df['new_text'] = df['new_text'].apply(remove_punc)

# %%
df['new_text'] = df['new_text'].apply(remove_stopwords)

# %%
# df['new_title'] = df['new_title'].apply(tokens)

# %%
# df['new_text'] = df['new_text'].apply(tokens)

# %%
# df['new_text'] = df['new_text'].apply(sent_tokens)

# %%
# df['new_title'] = df['new_title'].apply(bigrams)

# %%
# df['new_text'] = df['new_text'].apply(bigrams)

# %%
## tokenization did not change word cloud, bigrams function needs to be fixed - letters are separated to much need to be joined 
## somehow
import wordcloud
from wordcloud import WordCloud, STOPWORDS,ImageColorGenerator
from PIL import Image

# %%
stopwords = set(STOPWORDS)

# %%
fake_text = df[df['label'] == 'FAKE']

# %%
real_text = df[df['label'] == 'REAL']

# %%
real_txt = real_text['new_text']

# %%
real_title = real_text['new_title']

# %%
real_title = str(real_title)

# %%
real_txt = str(real_txt)

# %%
fake_txt = fake_text['new_text']

# %%
fake_title = fake_text['new_title']

# %%
fake_title = str(fake_title)

# %%
fake_txt = str(fake_txt)

# %%
plt.figure(figsize=(15,12))
wc = WordCloud().generate(fake_txt)
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.title('Fake article')
plt.show()

plt.figure(figsize=(15,12))
wc = WordCloud().generate(fake_title)
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.title('Fake title')
plt.show()

# %%
plt.figure(figsize=(15,12))
wc = WordCloud(stopwords=stopwords).generate(real_txt)
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.title('Real article')
plt.show()

plt.figure(figsize=(15,12))
wc = WordCloud(stopwords=stopwords).generate(real_title)
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.title("Real title")
plt.show()

# %%
training_data = df[['new_title','label']]

# %%
training_data.head()
# Out:
#                                                                     new_title  \
# 0                                                         smell hillarys fear
# 1  watch exact moment paul ryan committed political suicide trump rally video
# 2                                             kerry go paris gesture sympathy
# 3                        bernie supporters twitter erupt anger dnc tried warn
# 4                                             battle new york primary matters
#
#   label
# 0  FAKE
# 1  FAKE
# 2  REAL
# 3  FAKE
# 4  REAL

# %%
len(df)
# Out:
# 6335

# %%
training_data['label'] = training_data['label'].replace({'FAKE': 1, 'REAL':0})
# Out:
# C:\Users\willi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
train = training_data[0:5200]

# %%
test = training_data[5068:6335]

# %%
import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
vec = TfidfVectorizer(ngram_range=(1,2))
## ngrams (1, 2) increased vocab size

# %%
train_data = vec.fit_transform(train['new_title'])

# %%
#vec.idf_

# %%
vec.vocabulary_
# Out:
# {'smell': 30740,
#  'hillarys': 15756,
#  'fear': 12525,
#  'smell hillarys': 30742,
#  'hillarys fear': 15770,
#  'watch': 36614,
#  'exact': 11721,
#  'moment': 21270,
#  'paul': 24138,
#  'ryan': 28797,
#  'committed': 7257,
#  'political': 25003,
#  'suicide': 32093,
#  'trump': 34082,
#  'rally': 26652,
#  'video': 35847,
#  'watch exact': 36621,
#  'exact moment': 11722,
#  'moment paul': 21276,
#  'paul ryan': 24160,
#  'ryan committed': 28800,
#  'committed political': 7259,
#  'political suicide': 25036,
#  'suicide trump': 32101,
#  'trump rally': 34387,
#  'rally video': 26673,
#  'kerry': 18131,
#  'go': 14316,
#  'paris': 23925,
#  'gesture': 14072,
#  'sympathy': 32475,
#  'kerry go': 18136,
#  'go paris': 14331,
#  'paris gesture': 23932,
#  'gesture sympathy': 14073,
#  'bernie': 3561,
#  'supporters': 32210,
#  'twitter': 34874,
#  'erupt': 11462,
#  'anger': 1982,
#  'dnc': 10128,
#  'tried': 33965,
#  'warn': 36495,
#  'bernie supporters': 3570,
#  'supporters twitter': 32233,
#  'twitter erupt': 34878,
#  'erupt anger': 11463,
#  'anger dnc': 1983,
#  'dnc tried': 10144,
#  'tried warn': 33973,
#  'battle': 3287,
#  'new': 22164,
#  'york': 37786,
#  'primary': 25675,
#  'matters': 20434,
#  'battle new': 3301,
#  'new york': 22305,
#  'york primary': 37794,
#  'primary matters': 25687,
#  'tehran': 32880,
#  'usa': 35510,
#  'tehran usa': 32881,
#  'girl': 14190,
#  'horrified': 16075,
#  'watches': 36646,
#  'boyfriend': 4390,
#  'left': 18955,
#  'facetime': 12133,
#  'girl horrified': 14192,
#  'horrified watches': 16077,
#  'watches boyfriend': 36647,
#  'boyfriend left': 4392,
#  'left facetime': 18960,
#  'britains': 4612,
#  'schindler': 29341,
#  'dies': 9799,
#  '106': 54,
#  'britains schindler': 4614,
#  'schindler dies': 29342,
#  'dies 106': 9800,
#  'fact': 12141,
#  'check': 5989,
#  'clinton': 6453,
#  'commanderinchief': 7132,
#  'forum': 13442,
#  'fact check': 12142,
#  'check trump': 6000,
#  'trump clinton': 34161,
#  'clinton commanderinchief': 6512,
#  'commanderinchief forum': 7133,
#  'iran': 17273,
#  'reportedly': 27549,
#  'makes': 19996,
#  'push': 26297,
#  'uranium': 35321,
#  'concessions': 7375,
#  'nuclear': 22683,
#  'talks': 32692,
#  'iran reportedly': 17299,
#  'reportedly makes': 27558,
#  'makes new': 20013,
#  'new push': 22266,
#  'push uranium': 26310,
#  'uranium concessions': 35322,
#  'concessions nuclear': 7376,
#  'nuclear talks': 22701,
#  'three': 33336,
#  'clintons': 6749,
#  'iowa': 17239,
#  'glimpse': 14262,
#  'fire': 12936,
#  'eluded': 11017,
#  'hillary': 15590,
#  'campaign': 5122,
#  'three clintons': 33339,
#  'clintons iowa': 6790,
#  'iowa glimpse': 17247,
#  'glimpse fire': 14264,
#  'fire eluded': 12942,
#  'eluded hillary': 11018,
#  'hillary clintons': 15613,
#  'clintons campaign': 6765,
#  'donald': 10247,
#  'trumps': 34564,
#  'shockingly': 30191,
#  'weak': 36722,
#  'delegate': 9254,
#  'game': 13890,
#  'somehow': 30893,
#  'got': 14616,
#  'even': 11579,
#  'worse': 37532,
#  'donald trumps': 10253,
#  'trumps shockingly': 34643,
#  'shockingly weak': 30192,
#  'weak delegate': 36723,
#  'delegate game': 9256,
#  'game somehow': 13900,
#  'somehow got': 30894,
#  'got even': 14623,
#  'even worse': 11605,
#  'strong': 31878,
#  'solar': 30850,
#  'storm': 31738,
#  'tech': 32856,
#  'risks': 28240,
#  'today': 33529,
#  's0': 28829,
#  'news': 22312,
#  'oct262016': 23134,
#  'strong solar': 31887,
#  'solar storm': 30853,
#  'storm tech': 31746,
#  'tech risks': 32859,
#  'risks today': 28243,
#  'today s0': 33539,
#  's0 news': 28830,
#  'news oct262016': 22341,
#  'oct262016 video': 23135,
#  '10': 7,
#  'ways': 36703,
#  'america': 1717,
#  'preparing': 25434,
#  'world': 37463,
#  'war': 36395,
#  '10 ways': 22,
#  'ways america': 36704,
#  'america preparing': 1757,
#  'preparing world': 25438,
#  'world war': 37494,
#  'takes': 32626,
#  'cruz': 8437,
#  'lightly': 19263,
#  'trump takes': 34468,
#  'takes cruz': 32634,
#  'cruz lightly': 8478,
#  'women': 37316,
#  'lead': 18772,
#  'differently': 9828,
#  'women lead': 37327,
#  'lead differently': 18777,
#  'shocking': 30178,
#  'michele': 20893,
#  'obama': 22786,
#  'caught': 5607,
#  'glamorizing': 14252,
#  'date': 8763,
#  'rape': 26717,
#  'promoters': 25950,
#  'shocking michele': 30185,
#  'michele obama': 20894,
#  'obama hillary': 22856,
#  'hillary caught': 15611,
#  'caught glamorizing': 5618,
#  'glamorizing date': 14253,
#  'date rape': 8764,
#  'rape promoters': 26721,
#  'huge': 16237,
#  'trouble': 34044,
#  'noticed': 22626,
#  'sick': 30399,
#  'thing': 33165,
#  'hidden': 15508,
#  'picture': 24527,
#  'liberty': 19176,
#  'writers': 37631,
#  'hillary clinton': 15612,
#  'clinton huge': 6585,
#  'huge trouble': 16245,
#  'trouble america': 34045,
#  'america noticed': 1754,
#  'noticed sick': 22628,
#  'sick thing': 30405,
#  'thing hidden': 33169,
#  'hidden picture': 15511,
#  'picture liberty': 24531,
#  'liberty writers': 19180,
#  'writers news': 37632,
#  'whats': 36923,
#  'bill': 3776,
#  'doesnt': 10165,
#  'like': 19268,
#  'whats iran': 36930,
#  'iran bill': 17278,
#  'bill obama': 3802,
#  'obama doesnt': 22838,
#  'doesnt like': 10172,
#  'chart': 5964,
#  'explains': 11912,
#  'everything': 11678,
#  'need': 21984,
#  'know': 18365,
#  'partisanship': 24001,
#  'chart explains': 5966,
#  'explains everything': 11916,
#  'everything need': 11684,
#  'need know': 21993,
#  'know partisanship': 18381,
#  'partisanship america': 24002,
#  'slippery': 30681,
#  'slope': 30691,
#  'proposed': 26010,
#  'ban': 3148,
#  'muslims': 21667,
#  'slippery slope': 30682,
#  'slope trumps': 30692,
#  'trumps proposed': 34635,
#  'proposed ban': 26011,
#  'ban muslims': 3152,
#  'episode': 11405,
#  '160': 155,
#  'sunday': 32125,
#  'wire': 37241,
#  'hail': 14999,
#  'deplorables': 9544,
#  'special': 31090,
#  'guest': 14889,
#  'randy': 26700,
#  'episode 160': 11407,
#  '160 sunday': 156,
#  'sunday wire': 32129,
#  'wire hail': 37243,
#  'hail deplorables': 15000,
#  'deplorables special': 9550,
#  'special guest': 31093,
#  'guest randy': 14891,
#  'bipartisan': 3859,
#  'appeal': 2290,
#  'staten': 31502,
#  'island': 17472,
#  'clinton makes': 6617,
#  'makes bipartisan': 20000,
#  'bipartisan appeal': 3860,
#  'appeal staten': 2298,
#  'staten island': 31503,
#  'senate': 29736,
#  'majority': 19948,
#  'leaders': 18797,
#  'main': 19921,
#  'goal': 14341,
#  'gop': 14477,
#  'dont': 10299,
#  'scary': 29321,
#  'new senate': 22280,
#  'senate majority': 29753,
#  'majority leaders': 19950,
#  'leaders main': 18809,
#  'main goal': 19923,
#  'goal gop': 14342,
#  'gop dont': 14509,
#  'dont scary': 10323,
#  'inferno': 16817,
#  'overpopulation': 23710,
#  'myth': 21737,
#  'inferno overpopulation': 16818,
#  'overpopulation myth': 23711,
#  'antitrump': 2202,
#  'forces': 13334,
#  'seek': 29620,
#  'lastditch': 18601,
#  'revolt': 28011,
#  'antitrump forces': 2209,
#  'forces seek': 13349,
#  'seek lastditch': 29623,
#  'lastditch delegate': 18602,
#  'delegate revolt': 9261,
#  'sanders': 28929,
#  'trounces': 34059,
#  'va': 35624,
#  'make': 19953,
#  'difference': 9809,
#  'sanders trounces': 29010,
#  'trounces clinton': 34060,
#  'clinton va': 6730,
#  'va make': 35630,
#  'make difference': 19961,
#  'changing': 5877,
#  'slogan': 30688,
#  'prove': 26142,
#  'hes': 15469,
#  'racist': 26557,
#  'donald trump': 10251,
#  'trump changing': 34152,
#  'changing campaign': 5878,
#  'campaign slogan': 5192,
#  'slogan prove': 30689,
#  'prove hes': 26144,
#  'hes racist': 15487,
#  'pure': 26284,
#  'chaos': 5895,
#  'management': 20109,
#  'offers': 23174,
#  'governing': 14656,
#  'style': 31990,
#  'spoiler': 31224,
#  'alert': 1513,
#  'terrible': 32960,
#  'pure chaos': 26285,
#  'chaos donald': 5898,
#  'trumps campaign': 34576,
#  'campaign management': 5180,
#  'management offers': 20110,
#  'offers glimpse': 23176,
#  'glimpse governing': 14265,
#  'governing style': 14658,
#  'style spoiler': 31992,
#  'spoiler alert': 31225,
#  'alert terrible': 1518,
#  'syrian': 32514,
#  'report': 27512,
#  'november': 22648,
#  '2016': 287,
#  'military': 20979,
#  'deploys': 9557,
#  'advanced': 1183,
#  't90': 32555,
#  'tanks': 32721,
#  'aleppo': 1506,
#  'syrian war': 32529,
#  'war report': 36452,
#  'report november': 27532,
#  'november 2016': 22652,
#  '2016 syrian': 365,
#  'syrian military': 32523,
#  'military deploys': 20987,
#  'deploys advanced': 9558,
#  'advanced t90': 1185,
#  't90 battle': 32556,
#  'battle tanks': 3310,
#  'tanks aleppo': 32722,
#  'insiders': 16947,
#  'carly': 5448,
#  'crushed': 8427,
#  'gop insiders': 14535,
#  'insiders carly': 16948,
#  'carly crushed': 5449,
#  'jeffrey': 17680,
#  'sewell': 29948,
#  'et': 11510,
#  'al': 1466,
#  'metabiology': 20841,
#  'face': 12068,
#  'artificial': 2546,
#  'intelligence': 17023,
#  'jeffrey sewell': 17681,
#  'sewell et': 29949,
#  'et al': 11511,
#  'al metabiology': 1468,
#  'metabiology face': 20842,
#  'face face': 12076,
#  'face artificial': 12071,
#  'artificial intelligence': 2547,
#  'intelligence video': 17032,
#  'necessary': 21975,
#  'relax': 27316,
#  'stretch': 31852,
#  'necessary relax': 21979,
#  'relax stretch': 27317,
#  'brexit': 4528,
#  'encourages': 11191,
#  'uk': 34960,
#  'trade': 33769,
#  'noneu': 22557,
#  'states': 31504,
#  'including': 16673,
#  'russia': 28650,
#  'brexit encourages': 4531,
#  'encourages uk': 11193,
#  'uk trade': 34970,
#  'trade noneu': 33779,
#  'noneu states': 22558,
#  'states including': 31514,
#  'including russia': 16675,
#  'interview': 17109,
#  'socrates': 30835,
#  'another': 2063,
#  'day': 8793,
#  'life': 19217,
#  'empire': 11155,
#  'near': 21937,
#  'endgame': 11240,
#  'fools': 13287,
#  'ever': 11625,
#  'hope': 16039,
#  'change': 5826,
#  '2016 interview': 330,
#  'interview socrates': 17121,
#  'socrates another': 30836,
#  'another day': 2074,
#  'day life': 8813,
#  'life empire': 19226,
#  'empire near': 11157,
#  'near endgame': 21943,
#  'endgame fools': 11241,
#  'fools ever': 13288,
#  'ever hope': 11634,
#  'hope change': 16042,
#  'mike': 20959,
#  'pence': 24243,
#  'drapes': 10435,
#  'shawl': 30081,
#  'immodest': 16551,
#  'lady': 18487,
#  'justice': 17984,
#  'statue': 31543,
#  'onion': 23404,
#  'americas': 1857,
#  'finest': 12900,
#  'source': 30982,
#  'mike pence': 20965,
#  'pence drapes': 24248,
#  'drapes shawl': 10436,
#  'shawl immodest': 30082,
#  'immodest lady': 16552,
#  'lady justice': 18490,
#  'justice statue': 17993,
#  'statue onion': 31545,
#  'onion americas': 23405,
#  'americas finest': 1862,
#  'finest news': 12901,
#  'news source': 22358,
#  'first': 12987,
#  'hindu': 15796,
#  'woman': 37297,
#  'elected': 10861,
#  'congress': 7470,
#  'first ever': 13000,
#  'ever hindu': 11633,
#  'hindu woman': 15799,
#  'woman elected': 37304,
#  'elected congress': 10862,
#  'groped': 14802,
#  '2005': 251,
#  'weiner': 36841,
#  'sext': 29976,
#  'donald groped': 10248,
#  'groped hillary': 14803,
#  'hillary 2005': 15591,
#  '2005 trump': 252,
#  'trump weiner': 34522,
#  'weiner sext': 36848,
#  'exassistant': 11741,
#  'fbi': 12441,
#  'director': 9888,
#  'crime': 8294,
#  'family': 12286,
#  'exassistant fbi': 11742,
#  'fbi director': 12457,
#  'director clintons': 9890,
#  'clintons crime': 6771,
#  'crime family': 8297,
#  'wants': 36373,
#  'aggressively': 1326,
#  'interventionist': 17107,
#  'foreign': 13362,
#  'policy': 24981,
#  'hillary wants': 15738,
#  'wants aggressively': 36376,
#  'aggressively interventionist': 1329,
#  'interventionist foreign': 17108,
#  'foreign policy': 13377,
#  'parties': 23988,
#  'want': 36345,
#  'craft': 8210,
#  'populist': 25172,
#  'messages': 20836,
#  'parties want': 23992,
#  'want craft': 36349,
#  'craft populist': 8212,
#  'populist messages': 25173,
#  'messages 2016': 20837,
#  'take': 32571,
#  'wall': 36311,
#  'street': 31821,
#  'bids': 3703,
#  'goodbye': 14463,
#  'june': 17973,
#  'hike': 15569,
#  'first take': 13024,
#  'take wall': 32601,
#  'wall street': 36317,
#  'street bids': 31822,
#  'bids goodbye': 3704,
#  'goodbye june': 14464,
#  'june hike': 17974,
#  'real': 26874,
#  'disclosure': 9950,
#  'secret': 29526,
#  'alien': 1522,
#  'base': 3246,
#  'found': 13459,
#  'moons': 21365,
#  'tycho': 34925,
#  'crater': 8238,
#  'real disclosure': 26879,
#  'disclosure secret': 9954,
#  'secret alien': 29527,
#  'alien base': 1523,
#  'base found': 3251,
#  'found moons': 13477,
#  'moons tycho': 21366,
#  'tycho crater': 34926,
#  'homeless': 15981,
#  'protects': 26072,
#  'walk': 36277,
#  'fame': 12275,
#  'star': 31386,
#  'violent': 35951,
#  'leftists': 18983,
#  'homeless woman': 15987,
#  'woman protects': 37311,
#  'protects trumps': 26075,
#  'trumps walk': 34666,
#  'walk fame': 36280,
#  'fame star': 12277,
#  'star violent': 31393,
#  'violent leftists': 35954,
#  '320': 508,
#  'tweet': 34851,
#  'saturday': 29066,
#  'continues': 7701,
#  'mock': 21214,
#  'friday': 13691,
#  'meltdown': 20725,
#  '320 tweet': 509,
#  'tweet storm': 34854,
#  'storm saturday': 31745,
#  'saturday clinton': 29068,
#  'clinton continues': 6518,
#  'continues mock': 7709,
#  'mock trumps': 21216,
#  'trumps friday': 34596,
#  'friday meltdown': 13693,
#  '220': 420,
#  'significant': 30449,
#  'pipeline': 24572,
#  'spills': 31190,
#  'already': 1631,
#  'year': 37695,
#  'exposes': 11975,
#  'troubling': 34056,
#  'safety': 28869,
#  'record': 27073,
#  '220 significant': 421,
#  'significant pipeline': 30451,
#  'pipeline spills': 24585,
#  'spills already': 31191,
#  'already year': 1648,
#  'year exposes': 37699,
#  'exposes troubling': 11986,
#  'troubling safety': 34058,
#  'safety record': 28870,
#  'right': 28105,
#  'call': 4995,
#  'tough': 33705,
#  'afghanistan': 1255,
#  'obama makes': 22878,
#  'makes right': 20019,
#  'right call': 28109,
#  'call tough': 5016,
#  'tough afghanistan': 33706,
#  'race': 26506,
#  'rankings': 26708,
#  'dems': 9457,
#  'attack': 2701,
#  'lays': 18763,
#  'swingstate': 32443,
#  'groundwork': 14816,
#  'senate race': 29760,
#  'race rankings': 26525,
#  'rankings dems': 26709,
#  'dems attack': 9458,
#  'attack gop': 2716,
#  'gop lays': 14538,
#  'lays swingstate': 18765,
#  'swingstate groundwork': 32444,
#  'didnt': 9774,
#  'boy': 4373,
#  'raped': 26725,
#  'court': 8113,
#  'throws': 33362,
#  'muslim': 21642,
#  'migrant': 20944,
#  'child': 6075,
#  'sex': 29950,
#  'charge': 5907,
#  'germans': 14061,
#  'shock': 30165,
#  'didnt know': 9779,
#  'know boy': 18367,
#  'boy didnt': 4380,
#  'didnt want': 9785,
#  'want raped': 36361,
#  'raped court': 26726,
#  'court throws': 8149,
#  'throws muslim': 33364,
#  'muslim migrant': 21656,
#  'migrant child': 20946,
#  'child sex': 6083,
#  'sex charge': 29955,
#  'charge germans': 5908,
#  'germans shock': 14062,
#  'pieczenik': 24539,
#  'rogue': 28342,
#  'agents': 1311,
#  'wikileaks': 37064,
#  'spearheading': 31088,
#  'movement': 21499,
#  'stop': 31683,
#  'stealing': 31575,
#  'white': 36968,
#  'house': 16136,
#  'truthfeed': 34726,
#  'pieczenik rogue': 24540,
#  'rogue fbi': 28344,
#  'fbi agents': 12444,
#  'agents wikileaks': 1317,
#  'wikileaks spearheading': 37092,
#  'spearheading movement': 31089,
#  'movement stop': 21505,
#  'stop clintons': 31686,
#  'clintons stealing': 6815,
#  'stealing white': 31579,
#  'white house': 36979,
#  'house truthfeed': 16194,
#  'american': 1779,
#  'politics': 25059,
#  'reached': 26799,
#  'peak': 24233,
#  'polarization': 24887,
#  'american politics': 1802,
#  'politics reached': 25072,
#  'reached peak': 26801,
#  'peak polarization': 24234,
#  'antimuhammad': 2173,
#  'cartoon': 5516,
#  'contest': 7668,
#  'free': 13618,
#  'speech': 31112,
#  'deliberately': 9286,
#  'provocative': 26183,
#  'antimuhammad cartoon': 2174,
#  'cartoon contest': 5517,
#  'contest free': 7670,
#  'free speech': 13630,
#  'speech deliberately': 31121,
#  'deliberately provocative': 9288,
#  'provocative video': 26184,
#  'effects': 10801,
#  'substance': 32015,
#  'abuse': 842,
#  'individual': 16786,
#  'community': 7280,
#  'effects substance': 10803,
#  'substance abuse': 32016,
#  'abuse individual': 844,
#  'individual family': 16787,
#  'family community': 12289,
#  'tree': 33919,
#  'shaped': 30039,
#  'vertical': 35737,
#  'farms': 12372,
#  'grow': 14836,
#  '24': 434,
#  'acres': 978,
#  'urban': 35324,
#  'crops': 8377,
#  'tree shaped': 33920,
#  'shaped vertical': 30042,
#  'vertical farms': 35738,
#  'farms grow': 12373,
#  'grow 24': 14837,
#  '24 acres': 435,
#  'acres urban': 980,
#  'urban crops': 35325,
#  'comment': 7140,
#  'features': 12556,
#  'added': 1070,
#  'new comment': 22185,
#  'comment features': 7177,
#  'features added': 12557,
#  'worlds': 37507,
#  'newspapers': 22380,
#  'react': 26811,
#  'hebdo': 15328,
#  'worlds newspapers': 37512,
#  'newspapers react': 22381,
#  'react hebdo': 26812,
#  'hebdo attack': 15329,
#  'ying': 37782,
#  'yang': 37686,
#  'gold': 14410,
#  'silver': 30476,
#  'setup': 29932,
#  'ying yang': 37783,
#  'yang gold': 37687,
#  'gold silver': 14423,
#  'silver setup': 30486,
#  'closed': 6854,
#  'primaries': 25668,
#  'warped': 36539,
#  'democracy': 9350,
#  'closed primaries': 6857,
#  'primaries warped': 25672,
#  'warped democracy': 36540,
#  'police': 24910,
#  'turn': 34813,
#  'badges': 3073,
#  'rather': 26765,
#  'incite': 16661,
#  'violence': 35935,
#  'standing': 31371,
#  'rock': 28310,
#  'protestors': 26116,
#  'police turn': 24964,
#  'turn badges': 34814,
#  'badges rather': 3074,
#  'rather incite': 26766,
#  'incite violence': 16664,
#  'violence standing': 35946,
#  'standing rock': 31372,
#  'rock protestors': 28318,
#  'caused': 5641,
#  'tremendous': 33923,
#  'death': 8965,
#  'trump hillary': 34261,
#  'clinton caused': 6497,
#  'caused tremendous': 5643,
#  'tremendous death': 33924,
#  'detroit': 9716,
#  'womens': 37338,
#  'halloween': 15017,
#  'decorations': 9148,
#  'depict': 9538,
#  'reallife': 26910,
#  'horrors': 16081,
#  'shootings': 30233,
#  'detroit womens': 9719,
#  'womens halloween': 37339,
#  'halloween decorations': 15020,
#  'decorations depict': 9149,
#  'depict reallife': 9539,
#  'reallife horrors': 26911,
#  'horrors shootings': 16082,
#  'shootings police': 30237,
#  'police police': 24946,
#  'biden': 3680,
#  'surprise': 32297,
#  'biden makes': 3692,
#  'makes another': 19997,
#  'another surprise': 2092,
#  'surprise political': 32303,
#  'political stop': 25035,
#  'declining': 9141,
#  'favorability': 12431,
#  'numbers': 22734,
#  'context': 7682,
#  'clintons declining': 6773,
#  'declining favorability': 9143,
#  'favorability numbers': 12432,
#  'numbers context': 22735,
#  'quid': 26473,
#  'pro': 25777,
#  'quo': 26499,
#  'email': 11021,
#  'reveals': 27944,
#  'eyeing': 12047,
#  'ryans': 28824,
#  'relative': 27313,
#  'supreme': 32262,
#  'lenorelee': 19022,
#  'comment quid': 7195,
#  'quid pro': 26474,
#  'pro quo': 25778,
#  'quo wikileaks': 26501,
#  'wikileaks email': 37074,
#  'email reveals': 11042,
#  'reveals clinton': 27951,
#  'clinton campaign': 6492,
#  'campaign eyeing': 5155,
#  'eyeing paul': 12048,
#  'paul ryans': 24161,
#  'ryans relative': 28828,
#  'relative supreme': 27315,
#  'supreme court': 32263,
#  'court lenorelee': 8133,
#  'criminal': 8306,
#  'investigation': 17184,
#  'keeps': 18072,
#  'moving': 21526,
#  'forward': 13446,
#  'clinton criminal': 6525,
#  'criminal investigation': 8309,
#  'investigation keeps': 17193,
#  'keeps moving': 18077,
#  'moving forward': 21528,
#  'rubios': 28508,
#  'parting': 23993,
#  'shot': 30277,
#  'rubios parting': 28513,
#  'parting shot': 23994,
#  'shot trump': 30291,
#  'loretta': 19618,
#  'lynch': 19802,
#  'becomes': 3388,
#  'africanamerican': 1273,
#  'ag': 1280,
#  'loretta lynch': 19619,
#  'lynch becomes': 19804,
#  'becomes first': 3390,
#  'first africanamerican': 12988,
#  'africanamerican woman': 1274,
#  'woman ag': 37299,
#  'funny': 13825,
#  'republicans': 27644,
#  'upset': 35311,
#  'facebook': 12085,
#  'column': 7045,
#  'funny republicans': 13827,
#  'republicans upset': 27719,
#  'upset facebook': 35312,
#  'facebook column': 12091,
#  'checking': 6004,
#  'orlando': 23610,
#  'shooters': 30207,
#  'wife': 37040,
#  'knew': 18350,
#  'plan': 24638,
#  'fbi checking': 12453,
#  'checking orlando': 6007,
#  'orlando shooters': 23615,
#  'shooters wife': 30209,
#  'wife knew': 37046,
#  'knew attack': 18351,
#  'attack plan': 2728,
#  'plan didnt': 24656,
#  'didnt warn': 9786,
#  'warn police': 36498,
#  'google': 14465,
#  'youtube': 37844,
#  'purse': 26294,
#  'google youtube': 14476,
#  'youtube hillarys': 37848,
#  'hillarys purse': 15782,
#  'handicapping': 15057,
#  'hispanic': 15820,
#  'vote': 36041,
#  'gopers': 14595,
#  'handicapping hispanic': 15058,
#  'hispanic vote': 15823,
#  'vote 2016': 36042,
#  '2016 gopers': 323,
#  'truth': 34696,
#  'radio': 26584,
#  'laconia': 18481,
#  'incident': 16656,
#  'truth radio': 34717,
#  'radio laconia': 26588,
#  'laconia incident': 18482,
#  'establishment': 11493,
#  'nightmare': 22460,
#  'ted': 32867,
#  'vs': 36212,
#  'gop establishment': 14514,
#  'establishment nightmare': 11502,
#  'nightmare ted': 22465,
#  'ted cruz': 32868,
#  'cruz vs': 8505,
#  'vs donald': 36219,
#  'lost': 19678,
#  'poor': 25135,
#  'voters': 36091,
#  'south': 30995,
#  'carolina': 5462,
#  'big': 3706,
#  'margin': 20219,
#  'problem': 25808,
#  'revolution': 28018,
#  'bernie sanders': 3567,
#  'sanders lost': 28978,
#  'lost poor': 19692,
#  'poor voters': 25143,
#  'voters south': 36120,
#  'south carolina': 30999,
#  'carolina big': 5463,
#  'big margin': 3722,
#  'margin problem': 20220,
#  'problem political': 25818,
#  'political revolution': 25031,
#  'get': 14075,
#  'botox': 4350,
#  'get botox': 14084,
#  'jeb': 17657,
#  'bush': 4839,
#  'picks': 24521,
#  'endorsement': 11257,
#  'lindsey': 19360,
#  'graham': 14723,
#  'jeb bush': 17660,
#  'bush picks': 4872,
#  'picks endorsement': 24522,
#  'endorsement lindsey': 11262,
#  'lindsey graham': 19361,
#  'republican': 27604,
#  'enters': 11360,
#  'volatile': 36026,
#  'phase': 24441,
#  '2016 republican': 354,
#  'republican race': 27640,
#  'race enters': 26512,
#  'enters new': 11364,
#  'new volatile': 22298,
#  'volatile phase': 36027,
#  'hands': 15066,
#  'shoot': 30200,
#  'built': 4767,
#  'lie': 19195,
#  'hands dont': 15068,
#  'dont shoot': 10324,
#  'shoot built': 30201,
#  'built lie': 4769,
#  'lavrov': 18693,
#  'discuss': 9979,
#  'settlement': 29928,
#  'lavrov kerry': 18694,
#  'kerry discuss': 18134,
#  'discuss syrian': 9986,
#  'syrian settlement': 32528,
#  'breaking': 4457,
#  'doj': 10202,
#  'says': 29155,
#  'help': 15379,
#  'review': 27984,
#  '650k': 662,
#  'emails': 11052,
#  'breaking doj': 4464,
#  'doj says': 10211,
#  'says help': 29198,
#  'help review': 15394,
#  'review 650k': 27985,
#  '650k emails': 663,
#  'emails truthfeed': 11089,
#  'ouster': 23637,
#  'two': 34886,
#  'convention': 7776,
#  'cochairs': 6933,
#  'rejected': 27293,
#  'sanders call': 28941,
#  'call ouster': 5007,
#  'ouster two': 23638,
#  'two convention': 34891,
#  'convention cochairs': 7779,
#  'cochairs rejected': 6934,
#  'five': 13040,
#  'reasons': 26963,
#  'democratic': 9367,
#  'felt': 12637,
#  'competitive': 7303,
#  'five reasons': 13049,
#  'reasons new': 26969,
#  ...}

# %%
test_data = vec.transform(test['new_title'])

# %%
X_train = train_data
X_test = test_data
y_train = train.label
y_test = test.label

# %%
rt = RandomForestClassifier(n_estimators = 2000, criterion = 'gini', max_features='log2', random_state=1)

# %%
rt.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_features='log2', n_estimators=2000, random_state=1)

# %%
preds = rt.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve

# %%
## With bigrams and no tokenization - acc. went from 81.2% to 82.7%


accuracy_score(y_test, preds)
# Out:
# 0.8271507498026835

# %%
## With bigrams and no tokenization - true article preds went from 82% to 85%/ false article preds went from 80% to 81%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.82       623
#            1       0.81      0.86      0.84       644
#
#     accuracy                           0.83      1267
#    macro avg       0.83      0.83      0.83      1267
# weighted avg       0.83      0.83      0.83      1267

# %%
c = confusion_matrix(y_test, preds)
ax = sns.heatmap(c, annot=True, xticklabels=['Fake','Real'],yticklabels=['Fake','Real'],cbar=False)
ax.set_xlabel('Prediction')
ax.set_ylabel('Actual')
# Out:
# Text(33.0, 0.5, 'Actual')

# %%
confusion_matrix(y_test, preds)
# Out:
# array([[491, 132],
#        [ 87, 557]], dtype=int64)

# %%
FPR, TPR, _ = roc_curve(y_test, preds)

# %%
plt.plot(FPR, TPR)
plt.xlabel('FPR')
plt.ylabel('TPR')
# Out:
# Text(0, 0.5, 'TPR')

# %%
preds[:10]
# Out:
# array([1, 0, 0, 0, 1, 0, 0, 1, 1, 0], dtype=int64)

# %%
df_test= df[['title', 'new_title', 'label']]
df_test.iloc[:10]
# Out:
#                                                                                    title  \
# 0                                                           You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Political Suicide At A Trump Rally (VIDEO)
# 2                                            Kerry to go to Paris in gesture of sympathy
# 3   Bernie supporters on Twitter erupt in anger against the DNC: 'We tried to warn you!'
# 4                                       The Battle of New York: Why This Primary Matters
# 5                                                                            Tehran, USA
# 6              Girl Horrified At What She Watches Boyfriend Do After He Left FaceTime On
# 7                                                      ‘Britain’s Schindler’ Dies at 106
# 8                        Fact check: Trump and Clinton at the 'commander-in-chief' forum
# 9                Iran reportedly makes new push for uranium concessions in nuclear talks
#
#                                                                     new_title  \
# 0                                                         smell hillarys fear
# 1  watch exact moment paul ryan committed political suicide trump rally video
# 2                                             kerry go paris gesture sympathy
# 3                        bernie supporters twitter erupt anger dnc tried warn
# 4                                             battle new york primary matters
# 5                                                                  tehran usa
# 6                              girl horrified watches boyfriend left facetime
# 7                                                 britains schindler dies 106
# 8                             fact check trump clinton commanderinchief forum
# 9            iran reportedly makes new push uranium concessions nuclear talks
#
#   label
# 0  FAKE
# 1  FAKE
# 2  REAL
# 3  FAKE
# 4  REAL
# 5  FAKE
# 6  FAKE
# 7  REAL
# 8  REAL
# 9  REAL

# %%
def predict(x):
    x = vec.transform([x])
    x = x.toarray()
    pred = rt.predict(x)
    return pred

# %%
predict('donald trump wins election')
# Out:
# array([0], dtype=int64)

# %%
predict('reports on debate tonight')
# Out:
# array([0], dtype=int64)

# %%
predict('drinking bleach cures covid')
# Out:
# array([1], dtype=int64)

# %%
#when i changed this from is or isis to the islamic state it went from fake to real
## This prediction is wrong
predict('islamic state movement spreads across north africa')
# Out:
# array([1], dtype=int64)

# %%
import pickle
filename = 'RandmForest_modelbigrams'
pickle.dump(rt,open(filename, 'wb'))

# %%
filename2 = 'tfidfbasic_modelbigrams'
pickle.dump(vec,open(filename2, 'wb'))
